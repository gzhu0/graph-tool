# %% [markdown]
# #### Cactus Graph Script

# %%
import igraph
import graph_algorithms
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import igraph
# ----> 2 import graph_algorithms
#
# ModuleNotFoundError: No module named 'graph_algorithms'

# %% [markdown]
# Pseudocode
# 1. Find all F-cuts
# 2. Find all bridgeless cuts, get pairwise intersections for the corners
# 3. Get all basic cuts
# 4. Brides of the cactus are nontrivial basic cuts
# - Parition the graph
# 5. Recurse each subgraph until all base cuts are either a cycle or cube
# - Shrink each shore into a 'dummy vertex' and recurse
